# %%
import pandas as pd

data = pd.read_csv('dataset_full.csv')
data.head()
# Out:
#          Date  Tanggal  Bulan  Tahun  HargaJual  HargaBeli  Inflasi  \
# 0  31/07/2021       31      7   2021     843000     948000     1.52
# 1  30/07/2021       30      7   2021     850000     953000     1.52
# 2  29/07/2021       29      7   2021     842000     945000     1.52
# 3  28/07/2021       28      7   2021     837000     940000     1.52
# 4  27/07/2021       27      7   2021     837000     940000     1.52
#
#    HargaMinyak  KursJual  KursBeli
# 0        73.95   14570.0   14426.0
# 1        73.95   14570.0   14426.0
# 2        73.62   14570.0   14426.0
# 3        72.39   14561.0   14417.0
# 4        71.65   14566.0   14422.0

# %%
data
# Out:
#             Date  Tanggal  Bulan  Tahun  HargaJual  HargaBeli  Inflasi  \
# 0     31/07/2021       31      7   2021     843000     948000     1.52
# 1     30/07/2021       30      7   2021     850000     953000     1.52
# 2     29/07/2021       29      7   2021     842000     945000     1.52
# 3     28/07/2021       28      7   2021     837000     940000     1.52
# 4     27/07/2021       27      7   2021     837000     940000     1.52
# ...          ...      ...    ...    ...        ...        ...      ...
# 1666    5/1/2017        5      1   2017     506000     546000     3.49
# 1667    4/1/2017        4      1   2017     506000     546000     3.49
# 1668    3/1/2017        3      1   2017     506000     546000     3.49
# 1669    2/1/2017        2      1   2017     506000     546000     3.49
# 1670    1/1/2017        1      1   2017     506000     546000     3.49
#
#       HargaMinyak  KursJual  KursBeli
# 0           73.95   14570.0   14426.0
# ...

# %%
dataupdate = data.dropna()

# %%
dataupdate
# Out:
#             Date  Tanggal  Bulan  Tahun  HargaJual  HargaBeli  Inflasi  \
# 0     31/07/2021       31      7   2021     843000     948000     1.52
# 1     30/07/2021       30      7   2021     850000     953000     1.52
# 2     29/07/2021       29      7   2021     842000     945000     1.52
# 3     28/07/2021       28      7   2021     837000     940000     1.52
# 4     27/07/2021       27      7   2021     837000     940000     1.52
# ...          ...      ...    ...    ...        ...        ...      ...
# 1666    5/1/2017        5      1   2017     506000     546000     3.49
# 1667    4/1/2017        4      1   2017     506000     546000     3.49
# 1668    3/1/2017        3      1   2017     506000     546000     3.49
# 1669    2/1/2017        2      1   2017     506000     546000     3.49
# 1670    1/1/2017        1      1   2017     506000     546000     3.49
#
#       HargaMinyak  KursJual  KursBeli
# 0           73.95   14570.0   14426.0
# ...

# %%
dataupdate = data.dropna(data.date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6n/j59hpss55vzcl7g_gfry2zgh0000gp/T/ipykernel_1635/1565701930.py in <module>
# ----> 1 dataupdate = data.dropna(data.date)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date'
